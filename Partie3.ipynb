# %% [markdown]
# # Partie 3 : Le système solaire elliptique

# %% [markdown]
# A présent dans cette feuille, nous représentions les vrais orbites des planètes.

# %%
import data as d

# %%
d.espaceE
# Out:
#          Vitesse (km/h)  Demi-GA (km)  Angle de départ (radian)  Excentricité  \
# Mercure       1728000.0  5.800000e+08                  2.979310       0.20560
# Vénus         1260000.0  1.080000e+09                  1.166667       0.00678
# Terre         1044000.0  1.500000e+09                  0.696000       0.01671
# Mars           864000.0  2.280000e+09                  0.378947       0.09339
# Jupyter        468000.0  7.780000e+09                  0.060154       0.04839
# Saturne        360000.0  1.427000e+10                  0.025228       0.05390
# Uranus         252000.0  2.870000e+10                  0.008780       0.04726
# Neptune        180000.0  4.497000e+10                  0.004003       0.00859
#
#          Demi-PA (km)
# Mercure  5.676089e+08
# Vénus    1.079975e+09
# Terre    1.499791e+09
# Mars     2.270035e+09
# Jupyter  7.770886e+09
# Saturne  1.424926e+10
# Uranus   2.866793e+10
# Neptune  4.496834e+10

# %%
s = point2d((0,0))
for p in d.planete2[4:]:
    s += ellipse((0,0),p[1],p[4])
s
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
s = point2d((0,0))
for p in d.planete2[:4]:
    s += ellipse((0,0),p[1],p[4])
s
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# On remarque que les orbites semblent circulaires et pourtant ce sont bien des ellipses. En effet, la variation de distance entre le petit et le grand axe des orbites est immense à échelle humaine, mais représenté dans cette simulation, cela revient à avoir des cercles.
#
# Nous n'avons donc pas animé cette partie, jugeant cela inutile puisqu'on obtient exactement le même résulat que la feuille précédente.
